# %% [markdown]
# <a href="https://colab.research.google.com/github/SamuelGarcia-sg/PA/blob/main/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **LISTAS**

# %% [markdown]
# 1- Frutas

# %%
frutas = ["maçã", "banana", "laranja", "morango"]

print(frutas)
# Out:
# ['maçã', 'banana', 'laranja', 'morango']

# %% [markdown]
# 2- Nomes

# %%
nomes = ["Rebeca", "Guilherme", "Melissa", "Kyara"]

print(nomes[0])

print(nomes[1])

print(nomes[-1])
# Out:
# Rebeca
# Guilherme
# Kyara

# %% [markdown]
# 3- Cores

# %%
cores = ["vermelho", "azul", "verde"]

cores[1] = "amarelo"

print(cores)
# Out:
# ['vermelho', 'amarelo', 'verde']

# %% [markdown]
# 4- Alunos

# %%
alunos = ["Nicolas", "Wendel", "Pyetra"]

alunos.append("Petros")

print(alunos)
# Out:
# ['Nicolas', 'Wendel', 'Pyetra', 'Petros']

# %% [markdown]
# 5- Animais

# %%
animais = ["cachorro", "gato", "coelho", "passarinho"]

animais.remove("coelho")

print(animais)
# Out:
# ['cachorro', 'gato', 'passarinho']

# %% [markdown]
# **TUPLAS**

# %% [markdown]
# 1- Meses

# %%
meses = ("Janeiro", "Fevereiro", "Março", "Abril")

print(meses)
# Out:
# ('Janeiro', 'Fevereiro', 'Março', 'Abril')

# %% [markdown]
# 2- Números

# %%
numeros = (10, 20, 30, 40, 50)

print("Primeiro:", numeros[0])
print("Terceiro:", numeros[2])
print("Último:", numeros[-1])
# Out:
# Primeiro: 10
# Terceiro: 30
# Último: 50

# %% [markdown]
# 3- Aluno

# %%
aluno = ("Lucas", 17, "Informática")

print("Nome:", aluno[0])
print("Idade:", aluno[1])
print("Curso:", aluno[2])
# Out:
# Nome: Lucas
# Idade: 17
# Curso: Informática

# %% [markdown]
# 4- Cores

# %%
cores = ("vermelho", "azul", "verde")

cores[1] = "amarelo"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6297/691467408.py in <cell line: 0>()
#       1 cores = ("vermelho", "azul", "verde")
#       2
# ----> 3 cores[1] = "amarelo"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# 5- Números

# %%
numeros = (2, 4, 2, 6, 2, 8, 10)

qtd_dois = numeros.count(2)

print("O número 2 aparece:", qtd_dois, "vezes")
# Out:
# O número 2 aparece: 3 vezes
